# %%
name = input('Input your name: ')
age = int(input('Input your age: '))
print('Name: ',name)
print('Age: ',age)
print(type(name),type(age))
# Out:
# Name:  dao hoang duy
# Age:  36
# <class 'str'> <class 'int'>

# %%
age = age + 5
print(age)
# Out:
# 41

# %%
x = float(input('Enter your number phone:'))
print('Your number is: ',x)
# Out:
# Your number is:  909789614.0

# %%
print(name, age, x, sep = '--')
# Out:
# dao hoang duy--41--909789614.0

# %%
print(f'Name: {name} ,Age: {age} ,number is: ,{x}')
# Out:
# Name: dao hoang duy ,Age: 41 ,number is: ,909789614.0

# %%
print(f"""Name:',name, ', Age: ',{age}, 'number is: ',{x}""")
# Out:
# Name:',name, ', Age: ',41, 'number is: ',909789614.0

# %%
s = 'Hello'
a = 5
pi = 3.1415926
print(f'|{s:12}|')
print(f'|{a:12}|')
print(f'|{pi:12}|')
# Out:
# |Hello       |
# |           5|
# |   3.1415926|

# %%
print(f'|{s:>12}|')
print(f'|{a:^12}|')
print(f'|{pi:<12}|')
# Out:
# |       Hello|
# |     5      |
# |3.1415926   |

# %%
print(f'|{pi:.3f}|')
# Out:
# |3.142|
