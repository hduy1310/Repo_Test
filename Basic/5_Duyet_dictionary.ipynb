# %%
list_fruits = {'apple': 'quả táo', 'banana': 'quả chuối', 'orange': 'quả cam', 'mango': 'quả xoài', 'pineapple': 'Thơm'}
print(list_fruits)
# Out:
# {'apple': 'quả táo', 'banana': 'quả chuối', 'orange': 'quả cam', 'mango': 'quả xoài', 'pineapple': 'Thơm'}

# %%
print(list(list_fruits.keys()))
print(list(list_fruits.values()))
print(list(list_fruits.items()))
# Out:
# ['apple', 'banana', 'orange', 'mango', 'pineapple']
# ['quả táo', 'quả chuối', 'quả cam', 'quả xoài', 'Thơm']
# [('apple', 'quả táo'), ('banana', 'quả chuối'), ('orange', 'quả cam'), ('mango', 'quả xoài'), ('pineapple', 'Thơm')]

# %%
for x, y in list_fruits.items():
    print(f'{x} => {y}')
# Out:
# apple => quả táo
# banana => quả chuối
# orange => quả cam
# mango => quả xoài
# pineapple => Thơm
