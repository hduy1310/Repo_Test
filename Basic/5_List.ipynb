# %%
#empty
a = []
#list with integer
b = [1,2,3,4,5]
#list with string
c = ["apple","banana","cherry"]
#list with mixed data types
d = [1,"hello",3.14,True]
#list of list
e = [[1,2],[3,4],[5,6]]

# %%
print(b[0])
print(b[-1])
# Out:
# 1
# 5

# %%
b[2] = 'Hello'
print(b)
# Out:
# [1, 2, 'Hello', 4, 5]

# %%
#list methods
b.append(6)
print(b)
# Out:
# [1, 2, 'Hello', 4, 5, 6]

# %%
b.insert(3,'World')
b.insert(0,'Hello')
print(b)
# Out:
# ['Hello', 1, 2, 'Hello', 'World', 4, 5, 6]

# %%
#remove first appearance with value Hello
b.remove('Hello')
print(b)
# Out:
# [1, 2, 'Hello', 'World', 4, 5, 6]

# %%
#remove last appearance with value Hello
b.pop(6)
print(b)
# Out:
# [1, 2, 'Hello', 'World', 4, 5]

# %%
len(b)
# Out:
# 6

# %%
b.clear()
print(b)
# Out:
# []

# %%
list=[5,6,1,5,7]
list.sort()

# %%
print(list)
# Out:
# [1, 5, 5, 6, 7]

# %%
list.sort(reverse=True)
print(list)
# Out:
# [7, 6, 5, 5, 1]

# %%
list.sort(reverse=False)
print(list)
# Out:
# [1, 5, 5, 6, 7]

# %%
list.reverse()
print(list)
# Out:
# [7, 6, 5, 5, 1]

# %%
print(list.count(5))
print(list.index(5))
# Out:
# 2

# %%
print(list)
# Out:
# [7, 6, 5, 5, 1]

# %%
def index(list,x):
        found=[]
        for i in range(len(list)):
            if list[i]==x:
                  found.append(i)
            return found

# %%
found = index(list,7)
print(index)
# Out:
# <function index at 0x000001D6EC8BB740>
