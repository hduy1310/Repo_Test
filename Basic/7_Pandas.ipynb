# %%
import pandas as pd

# %%
my_data = {
    'cars': ['Toyota','Honda','Ford','BMW'],
    'price':[24000,22000,26000,35000]
}
#create a DataFrame
df_cars = pd.DataFrame(my_data)

# %%
df_cars.head()
# Out:
#      cars  price
# 0  Toyota  24000
# 1   Honda  22000
# 2    Ford  26000
# 3     BMW  35000

# %%
a = ['Toyota','Honda','Ford','BMW']
sr = pd.Series(a)
print(sr)
# Out:
# 0    Toyota
# 1     Honda
# 2      Ford
# 3       BMW
# dtype: object

# %%
print(df_cars.loc[1])
# Out:
# cars     Honda
# price    22000
# Name: 1, dtype: object

# %%
print(df_cars.loc[[1,3]])
# Out:
#     cars  price
# 1  Honda  22000
# 3    BMW  35000

# %%
print(sr[1])
# Out:
# Honda

# %%
my_data = {
    'cars': ['Toyota','Honda','Ford','BMW'],
    'price':[24000,22000,26000,35000]
}
df_cars = pd.DataFrame(my_data, index = ['CAR01','CAR02','CAR03','CAR04'])
df_cars.head()
# Out:
#          cars  price
# CAR01  Toyota  24000
# CAR02   Honda  22000
# CAR03    Ford  26000
# CAR04     BMW  35000
