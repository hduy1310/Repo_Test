# %%
import matplotlib as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
x = np.linspace(1, 10, 10, dtype=int)
y = 2*x + 5
 
plt.plot(x, y, marker='o', linestyle='-.', color='g', ms=5)
plt.title("Line Plot of y = 2x + 5")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 4
#       1 x = np.linspace(1, 10, 10, dtype=int)
#       2 y = 2*x + 5
# ----> 4 plt.plot(x, y, marker='o', linestyle='-.', color='g', ms=5)
#       5 plt.title("Line Plot of y = 2x + 5")
#       6 plt.xlabel("X-axis")
#
# File c:\Users\DUYDH\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
reading_scores = np.random.normal(75, 10, 200)
writing_scores = reading_scores + np.random.normal(0, 5, 200)
plt.scatter(reading_scores, writing_scores, alpha=0.6)
plt.title("Reading vs Writing Scores")
plt.xlabel("Reading Scores")
plt.ylabel("Writing Scores")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 reading_scores = np.random.normal(75, 10, 200)
#       2 writing_scores = reading_scores + np.random.normal(0, 5, 200)
# ----> 3 plt.scatter(reading_scores, writing_scores, alpha=0.6)
#       4 plt.title("Reading vs Writing Scores")
#       5 plt.xlabel("Reading Scores")
#
# NameError: name 'plt' is not defined

# %%
#bieu do tron
plt.pie(sales, labels=products, autopct='%1.0f%%')
plt.title("Smartphone Sales Distribution in 2025")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 #bieu do tron
# ----> 2 plt.pie(sales, labels=products, autopct='%1.0f%%')
#       3 plt.title("Smartphone Sales Distribution in 2025")
#       4 plt.show()
#
# File c:\Users\DUYDH\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pie'

# %%
x = np.linspace(1, 10, 10, dtype=int)
y = 2*x + 5
 
plt.plot(x, y, marker='o', linestyle='-.', color='g', ms=5)
plt.title("Line Plot of y = 2x + 5")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 4
#       1 x = np.linspace(1, 10, 10, dtype=int)
#       2 y = 2*x + 5
# ----> 4 plt.plot(x, y, marker='o', linestyle='-.', color='g', ms=5)
#       5 plt.title("Line Plot of y = 2x + 5")
#       6 plt.xlabel("X-axis")
#
# File c:\Users\DUYDH\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'plot'

# %%
x = np.random.normal(0, 10, 100)
plt.hist(x, bins=15, color='skyblue', edgecolor='black')
plt.title("Histogram of Normally Distributed Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 x = np.random.normal(0, 10, 100)
# ----> 2 plt.hist(x, bins=15, color='skyblue', edgecolor='black')
#       3 plt.title("Histogram of Normally Distributed Data")
#       4 plt.xlabel("Value")
#
# File c:\Users\DUYDH\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'hist'

# %%
# redraw using seaborn for better aesthetics
sns.histplot(x, bins=15, kde=True, color='skyblue')
plt.title("Histogram of Normally Distributed Data with KDE")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 # redraw using seaborn for better aesthetics
#       2 sns.histplot(x, bins=15, kde=True, color='skyblue')
# ----> 3 plt.title("Histogram of Normally Distributed Data with KDE")
#       4 plt.xlabel("Value")
#       5 plt.ylabel("Frequency")
#
# File c:\Users\DUYDH\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'title'
