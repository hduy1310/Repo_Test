# %%
#.1 Hello
print('Hello, Python!')
# Out:
# Hello, Python!

# %%
#.2
name = input('Enter your name: ')
print('Hello ', name)
# Out:
# Hello  Duy

# %%
#.3 In các phép toán
x = int(input('Enter x: '))
y = int(input('Enter y: '))
print('x + y = ',x+y)
print('x - y = ',x-y)
print('x * y = ',x*y)
print('x / y = ',x/y)
# Out:
# x + y =  12
# x - y =  6
# x * y =  27
# x / y =  3.0

# %%
#4.Tính diện tích hình tròn
pi = 3.14159
R  = float(input('Enter ban kinh hinh tron: '))
U = str(input('Input unit: '))
S = pi*R
print('Dien tich hinh tron la: ',S,' ',U,'2')
# Out:
# Dien tich hinh tron la:  31.4159   M 2

# %%
#5.Tính độ F từ độ C
C = int(input('Enter do C: '))
result = C*9/5+32
print("Nhiet do F: ",result)
# Out:
# Nhiet do F:  50.0

# %%
#6.Kiểm tra số chẵn lẻ
number = float(input('Nhap so can kiem tra: '))
if number%2 == 0:
    print('So ',number,'là số chẵn')
elif number%2 != 0:
    print('So ',number,'không phải là số chẵn')
# Out:
# So  19.0 không phải là số chẵn

# %%
#7.Hoán đổi giá trị 2 biến
x = input('Enter biến x: ')
y = input('Enter biến y: ')
z=x
x=y
y=z
print('x là : ',x)
print('y là : ',y)
# Out:
# x là :  9
# y là :  6

# %%
#7.Hoán đổi giá trị 2 biến
x = input('Enter biến x: ')
y = input('Enter biến y: ')
z=x
x=y
y=z
print('x là : ',x)
print('y là : ',y)

# %%
#8.Tính lãi kép
P=float(input('Nhập số tiền gốc: '))
r=float(input('Nhập lãi suất năm: '))
n=int(input('Nhập số lần trả lãi trong năm: '))
t=int(input('Nhập số năm: '))

result = pow(P*(1+r/n),n*t)

print(result)
# Out:
# 1.6834112196028233e+148
