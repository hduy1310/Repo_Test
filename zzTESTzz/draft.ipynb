# %%
#2.Convert Celsius to Fahrenheit. Formular: F = (9/5) * C + 32
def convert_fahrenheit_to_celsius (x):
    result = (9/5) * x + 32
    return result
def convert_celsius_to_fahrenheit (x):
    result = (x-32) * (5/9)
    return result
def get_data():
    type = input('Enter type (C\F): ')
    value = input('Enter value: ')
    return type
    return value
def swap():
if type == 'C':
    convert_fahrenheit_to_celsius (value)
elif type == 'F':
    convert_celsius_to_fahrenheit (value)
def final():
    while True:
        get_data()
        swap()

# %%
print('Hello Python ssaljslfkj')
# Out:
# Hello Python
